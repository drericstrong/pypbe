# %%
from pypbe import PBE
alg1=PBE(3,6,add_val=0,num_ability=6,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg2=PBE(3,6,add_val=0,num_ability=6,num_arrays=3,reroll=0,best_dice=3,best_ability=6)
alg3=PBE(3,6,add_val=0,num_ability=6,num_arrays=6,reroll=0,best_dice=3,best_ability=6)
alg4=PBE(3,6,add_val=0,num_ability=6,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg5=PBE(3,6,add_val=0,num_ability=6,num_arrays=3,reroll=1,best_dice=3,best_ability=6)
alg6=PBE(3,6,add_val=0,num_ability=6,num_arrays=6,reroll=1,best_dice=3,best_ability=6)
alg7=PBE(3,6,add_val=0,num_ability=6,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg8=PBE(3,6,add_val=0,num_ability=6,num_arrays=3,reroll=2,best_dice=3,best_ability=6)
alg9=PBE(3,6,add_val=0,num_ability=6,num_arrays=6,reroll=2,best_dice=3,best_ability=6)
alg10=PBE(3,6,add_val=0,num_ability=7,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg11=PBE(3,6,add_val=0,num_ability=7,num_arrays=3,reroll=0,best_dice=3,best_ability=6)
alg12=PBE(3,6,add_val=0,num_ability=7,num_arrays=6,reroll=0,best_dice=3,best_ability=6)
alg13=PBE(3,6,add_val=0,num_ability=7,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg14=PBE(3,6,add_val=0,num_ability=7,num_arrays=3,reroll=1,best_dice=3,best_ability=6)
alg15=PBE(3,6,add_val=0,num_ability=7,num_arrays=6,reroll=1,best_dice=3,best_ability=6)
alg16=PBE(3,6,add_val=0,num_ability=7,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg17=PBE(3,6,add_val=0,num_ability=7,num_arrays=3,reroll=2,best_dice=3,best_ability=6)
alg18=PBE(3,6,add_val=0,num_ability=7,num_arrays=6,reroll=2,best_dice=3,best_ability=6)
alg19=PBE(3,6,add_val=0,num_ability=9,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg20=PBE(3,6,add_val=0,num_ability=9,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg21=PBE(3,6,add_val=0,num_ability=9,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg22=PBE(3,6,add_val=0,num_ability=12,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg23=PBE(3,6,add_val=0,num_ability=12,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg24=PBE(3,6,add_val=0,num_ability=12,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg25=PBE(4,6,add_val=0,num_ability=6,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg26=PBE(4,6,add_val=0,num_ability=6,num_arrays=3,reroll=0,best_dice=3,best_ability=6)
alg27=PBE(4,6,add_val=0,num_ability=6,num_arrays=6,reroll=0,best_dice=3,best_ability=6)
alg28=PBE(4,6,add_val=0,num_ability=6,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg29=PBE(4,6,add_val=0,num_ability=6,num_arrays=3,reroll=1,best_dice=3,best_ability=6)
alg30=PBE(4,6,add_val=0,num_ability=6,num_arrays=6,reroll=1,best_dice=3,best_ability=6)
alg31=PBE(4,6,add_val=0,num_ability=6,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg32=PBE(4,6,add_val=0,num_ability=6,num_arrays=3,reroll=2,best_dice=3,best_ability=6)
alg33=PBE(4,6,add_val=0,num_ability=6,num_arrays=6,reroll=2,best_dice=3,best_ability=6)
alg34=PBE(4,6,add_val=0,num_ability=7,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg35=PBE(4,6,add_val=0,num_ability=7,num_arrays=3,reroll=0,best_dice=3,best_ability=6)
alg36=PBE(4,6,add_val=0,num_ability=7,num_arrays=6,reroll=0,best_dice=3,best_ability=6)
alg37=PBE(4,6,add_val=0,num_ability=7,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg38=PBE(4,6,add_val=0,num_ability=7,num_arrays=3,reroll=1,best_dice=3,best_ability=6)
alg39=PBE(4,6,add_val=0,num_ability=7,num_arrays=6,reroll=1,best_dice=3,best_ability=6)
alg40=PBE(4,6,add_val=0,num_ability=7,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg41=PBE(4,6,add_val=0,num_ability=7,num_arrays=3,reroll=2,best_dice=3,best_ability=6)
alg42=PBE(4,6,add_val=0,num_ability=7,num_arrays=6,reroll=2,best_dice=3,best_ability=6)
alg43=PBE(4,6,add_val=0,num_ability=9,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg44=PBE(4,6,add_val=0,num_ability=9,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg45=PBE(4,6,add_val=0,num_ability=9,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg46=PBE(4,6,add_val=0,num_ability=12,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg47=PBE(4,6,add_val=0,num_ability=12,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg48=PBE(4,6,add_val=0,num_ability=12,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg49=PBE(2,6,add_val=6,num_ability=6,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg50=PBE(2,6,add_val=6,num_ability=6,num_arrays=3,reroll=0,best_dice=2,best_ability=6)
alg51=PBE(2,6,add_val=6,num_ability=6,num_arrays=6,reroll=0,best_dice=2,best_ability=6)
alg52=PBE(2,6,add_val=6,num_ability=6,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg53=PBE(2,6,add_val=6,num_ability=6,num_arrays=3,reroll=1,best_dice=2,best_ability=6)
alg54=PBE(2,6,add_val=6,num_ability=6,num_arrays=6,reroll=1,best_dice=2,best_ability=6)
alg55=PBE(2,6,add_val=6,num_ability=6,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg56=PBE(2,6,add_val=6,num_ability=6,num_arrays=3,reroll=2,best_dice=2,best_ability=6)
alg57=PBE(2,6,add_val=6,num_ability=6,num_arrays=6,reroll=2,best_dice=2,best_ability=6)
alg58=PBE(2,6,add_val=6,num_ability=7,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg59=PBE(2,6,add_val=6,num_ability=7,num_arrays=3,reroll=0,best_dice=2,best_ability=6)
alg60=PBE(2,6,add_val=6,num_ability=7,num_arrays=6,reroll=0,best_dice=2,best_ability=6)
alg61=PBE(2,6,add_val=6,num_ability=7,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg62=PBE(2,6,add_val=6,num_ability=7,num_arrays=3,reroll=1,best_dice=2,best_ability=6)
alg63=PBE(2,6,add_val=6,num_ability=7,num_arrays=6,reroll=1,best_dice=2,best_ability=6)
alg64=PBE(2,6,add_val=6,num_ability=7,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg65=PBE(2,6,add_val=6,num_ability=7,num_arrays=3,reroll=2,best_dice=2,best_ability=6)
alg66=PBE(2,6,add_val=6,num_ability=7,num_arrays=6,reroll=2,best_dice=2,best_ability=6)
alg67=PBE(2,6,add_val=6,num_ability=9,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg68=PBE(2,6,add_val=6,num_ability=9,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg69=PBE(2,6,add_val=6,num_ability=9,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg70=PBE(2,6,add_val=6,num_ability=12,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg71=PBE(2,6,add_val=6,num_ability=12,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg72=PBE(2,6,add_val=6,num_ability=12,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg73=PBE(5,6,add_val=0,num_ability=6,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg74=PBE(5,6,add_val=0,num_ability=6,num_arrays=3,reroll=0,best_dice=3,best_ability=6)
alg75=PBE(5,6,add_val=0,num_ability=6,num_arrays=6,reroll=0,best_dice=3,best_ability=6)
alg76=PBE(5,6,add_val=0,num_ability=6,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg77=PBE(5,6,add_val=0,num_ability=6,num_arrays=3,reroll=1,best_dice=3,best_ability=6)
alg78=PBE(5,6,add_val=0,num_ability=6,num_arrays=6,reroll=1,best_dice=3,best_ability=6)
alg79=PBE(5,6,add_val=0,num_ability=6,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg80=PBE(5,6,add_val=0,num_ability=6,num_arrays=3,reroll=2,best_dice=3,best_ability=6)
alg81=PBE(5,6,add_val=0,num_ability=6,num_arrays=6,reroll=2,best_dice=3,best_ability=6)
alg82=PBE(5,6,add_val=0,num_ability=7,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg83=PBE(5,6,add_val=0,num_ability=7,num_arrays=3,reroll=0,best_dice=3,best_ability=6)
alg84=PBE(5,6,add_val=0,num_ability=7,num_arrays=6,reroll=0,best_dice=3,best_ability=6)
alg85=PBE(5,6,add_val=0,num_ability=7,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg86=PBE(5,6,add_val=0,num_ability=7,num_arrays=3,reroll=1,best_dice=3,best_ability=6)
alg87=PBE(5,6,add_val=0,num_ability=7,num_arrays=6,reroll=1,best_dice=3,best_ability=6)
alg88=PBE(5,6,add_val=0,num_ability=7,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg89=PBE(5,6,add_val=0,num_ability=7,num_arrays=3,reroll=2,best_dice=3,best_ability=6)
alg90=PBE(5,6,add_val=0,num_ability=7,num_arrays=6,reroll=2,best_dice=3,best_ability=6)
alg91=PBE(5,6,add_val=0,num_ability=9,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg92=PBE(5,6,add_val=0,num_ability=9,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg93=PBE(5,6,add_val=0,num_ability=9,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg94=PBE(5,6,add_val=0,num_ability=12,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg95=PBE(5,6,add_val=0,num_ability=12,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg96=PBE(5,6,add_val=0,num_ability=12,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg97=PBE(4,4,add_val=2,num_ability=6,num_arrays=1,reroll=0,best_dice=4,best_ability=6)
alg98=PBE(4,4,add_val=2,num_ability=6,num_arrays=3,reroll=0,best_dice=4,best_ability=6)
alg99=PBE(4,4,add_val=2,num_ability=6,num_arrays=6,reroll=0,best_dice=4,best_ability=6)
alg100=PBE(4,4,add_val=2,num_ability=6,num_arrays=1,reroll=1,best_dice=4,best_ability=6)
alg101=PBE(4,4,add_val=2,num_ability=6,num_arrays=3,reroll=1,best_dice=4,best_ability=6)
alg102=PBE(4,4,add_val=2,num_ability=6,num_arrays=6,reroll=1,best_dice=4,best_ability=6)
alg103=PBE(4,4,add_val=2,num_ability=6,num_arrays=1,reroll=2,best_dice=4,best_ability=6)
alg104=PBE(4,4,add_val=2,num_ability=6,num_arrays=3,reroll=2,best_dice=4,best_ability=6)
alg105=PBE(4,4,add_val=2,num_ability=6,num_arrays=6,reroll=2,best_dice=4,best_ability=6)
alg106=PBE(4,4,add_val=2,num_ability=7,num_arrays=1,reroll=0,best_dice=4,best_ability=6)
alg107=PBE(4,4,add_val=2,num_ability=7,num_arrays=3,reroll=0,best_dice=4,best_ability=6)
alg108=PBE(4,4,add_val=2,num_ability=7,num_arrays=6,reroll=0,best_dice=4,best_ability=6)
alg109=PBE(4,4,add_val=2,num_ability=7,num_arrays=1,reroll=1,best_dice=4,best_ability=6)
alg110=PBE(4,4,add_val=2,num_ability=7,num_arrays=3,reroll=1,best_dice=4,best_ability=6)
alg111=PBE(4,4,add_val=2,num_ability=7,num_arrays=6,reroll=1,best_dice=4,best_ability=6)
alg112=PBE(4,4,add_val=2,num_ability=7,num_arrays=1,reroll=2,best_dice=4,best_ability=6)
alg113=PBE(4,4,add_val=2,num_ability=7,num_arrays=3,reroll=2,best_dice=4,best_ability=6)
alg114=PBE(4,4,add_val=2,num_ability=7,num_arrays=6,reroll=2,best_dice=4,best_ability=6)
alg115=PBE(4,4,add_val=2,num_ability=9,num_arrays=1,reroll=0,best_dice=4,best_ability=6)
alg116=PBE(4,4,add_val=2,num_ability=9,num_arrays=1,reroll=1,best_dice=4,best_ability=6)
alg117=PBE(4,4,add_val=2,num_ability=9,num_arrays=1,reroll=2,best_dice=4,best_ability=6)
alg118=PBE(4,4,add_val=2,num_ability=12,num_arrays=1,reroll=0,best_dice=4,best_ability=6)
alg119=PBE(4,4,add_val=2,num_ability=12,num_arrays=1,reroll=1,best_dice=4,best_ability=6)
alg120=PBE(4,4,add_val=2,num_ability=12,num_arrays=1,reroll=2,best_dice=4,best_ability=6)
alg121=PBE(5,4,add_val=2,num_ability=6,num_arrays=1,reroll=0,best_dice=4,best_ability=6)
alg122=PBE(5,4,add_val=2,num_ability=6,num_arrays=3,reroll=0,best_dice=4,best_ability=6)
alg123=PBE(5,4,add_val=2,num_ability=6,num_arrays=6,reroll=0,best_dice=4,best_ability=6)
alg124=PBE(5,4,add_val=2,num_ability=6,num_arrays=1,reroll=1,best_dice=4,best_ability=6)
alg125=PBE(5,4,add_val=2,num_ability=6,num_arrays=3,reroll=1,best_dice=4,best_ability=6)
alg126=PBE(5,4,add_val=2,num_ability=6,num_arrays=6,reroll=1,best_dice=4,best_ability=6)
alg127=PBE(5,4,add_val=2,num_ability=6,num_arrays=1,reroll=2,best_dice=4,best_ability=6)
alg128=PBE(5,4,add_val=2,num_ability=6,num_arrays=3,reroll=2,best_dice=4,best_ability=6)
alg129=PBE(5,4,add_val=2,num_ability=6,num_arrays=6,reroll=2,best_dice=4,best_ability=6)
alg130=PBE(5,4,add_val=2,num_ability=7,num_arrays=1,reroll=0,best_dice=4,best_ability=6)
alg131=PBE(5,4,add_val=2,num_ability=7,num_arrays=3,reroll=0,best_dice=4,best_ability=6)
alg132=PBE(5,4,add_val=2,num_ability=7,num_arrays=6,reroll=0,best_dice=4,best_ability=6)
alg133=PBE(5,4,add_val=2,num_ability=7,num_arrays=1,reroll=1,best_dice=4,best_ability=6)
alg134=PBE(5,4,add_val=2,num_ability=7,num_arrays=3,reroll=1,best_dice=4,best_ability=6)
alg135=PBE(5,4,add_val=2,num_ability=7,num_arrays=6,reroll=1,best_dice=4,best_ability=6)
alg136=PBE(5,4,add_val=2,num_ability=7,num_arrays=1,reroll=2,best_dice=4,best_ability=6)
alg137=PBE(5,4,add_val=2,num_ability=7,num_arrays=3,reroll=2,best_dice=4,best_ability=6)
alg138=PBE(5,4,add_val=2,num_ability=7,num_arrays=6,reroll=2,best_dice=4,best_ability=6)
alg139=PBE(5,4,add_val=2,num_ability=9,num_arrays=1,reroll=0,best_dice=4,best_ability=6)
alg140=PBE(5,4,add_val=2,num_ability=9,num_arrays=1,reroll=1,best_dice=4,best_ability=6)
alg141=PBE(5,4,add_val=2,num_ability=9,num_arrays=1,reroll=2,best_dice=4,best_ability=6)
alg142=PBE(5,4,add_val=2,num_ability=12,num_arrays=1,reroll=0,best_dice=4,best_ability=6)
alg143=PBE(5,4,add_val=2,num_ability=12,num_arrays=1,reroll=1,best_dice=4,best_ability=6)
alg144=PBE(5,4,add_val=2,num_ability=12,num_arrays=1,reroll=2,best_dice=4,best_ability=6)
alg145=PBE(3,4,add_val=6,num_ability=6,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg146=PBE(3,4,add_val=6,num_ability=6,num_arrays=3,reroll=0,best_dice=3,best_ability=6)
alg147=PBE(3,4,add_val=6,num_ability=6,num_arrays=6,reroll=0,best_dice=3,best_ability=6)
alg148=PBE(3,4,add_val=6,num_ability=6,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg149=PBE(3,4,add_val=6,num_ability=6,num_arrays=3,reroll=1,best_dice=3,best_ability=6)
alg150=PBE(3,4,add_val=6,num_ability=6,num_arrays=6,reroll=1,best_dice=3,best_ability=6)
alg151=PBE(3,4,add_val=6,num_ability=6,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg152=PBE(3,4,add_val=6,num_ability=6,num_arrays=3,reroll=2,best_dice=3,best_ability=6)
alg153=PBE(3,4,add_val=6,num_ability=6,num_arrays=6,reroll=2,best_dice=3,best_ability=6)
alg154=PBE(3,4,add_val=6,num_ability=7,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg155=PBE(3,4,add_val=6,num_ability=7,num_arrays=3,reroll=0,best_dice=3,best_ability=6)
alg156=PBE(3,4,add_val=6,num_ability=7,num_arrays=6,reroll=0,best_dice=3,best_ability=6)
alg157=PBE(3,4,add_val=6,num_ability=7,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg158=PBE(3,4,add_val=6,num_ability=7,num_arrays=3,reroll=1,best_dice=3,best_ability=6)
alg159=PBE(3,4,add_val=6,num_ability=7,num_arrays=6,reroll=1,best_dice=3,best_ability=6)
alg160=PBE(3,4,add_val=6,num_ability=7,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg161=PBE(3,4,add_val=6,num_ability=7,num_arrays=3,reroll=2,best_dice=3,best_ability=6)
alg162=PBE(3,4,add_val=6,num_ability=7,num_arrays=6,reroll=2,best_dice=3,best_ability=6)
alg163=PBE(3,4,add_val=6,num_ability=9,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg164=PBE(3,4,add_val=6,num_ability=9,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg165=PBE(3,4,add_val=6,num_ability=9,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg166=PBE(3,4,add_val=6,num_ability=12,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg167=PBE(3,4,add_val=6,num_ability=12,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg168=PBE(3,4,add_val=6,num_ability=12,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg169=PBE(4,4,add_val=6,num_ability=6,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg170=PBE(4,4,add_val=6,num_ability=6,num_arrays=3,reroll=0,best_dice=3,best_ability=6)
alg171=PBE(4,4,add_val=6,num_ability=6,num_arrays=6,reroll=0,best_dice=3,best_ability=6)
alg172=PBE(4,4,add_val=6,num_ability=6,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg173=PBE(4,4,add_val=6,num_ability=6,num_arrays=3,reroll=1,best_dice=3,best_ability=6)
alg174=PBE(4,4,add_val=6,num_ability=6,num_arrays=6,reroll=1,best_dice=3,best_ability=6)
alg175=PBE(4,4,add_val=6,num_ability=6,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg176=PBE(4,4,add_val=6,num_ability=6,num_arrays=3,reroll=2,best_dice=3,best_ability=6)
alg177=PBE(4,4,add_val=6,num_ability=6,num_arrays=6,reroll=2,best_dice=3,best_ability=6)
alg178=PBE(4,4,add_val=6,num_ability=7,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg179=PBE(4,4,add_val=6,num_ability=7,num_arrays=3,reroll=0,best_dice=3,best_ability=6)
alg180=PBE(4,4,add_val=6,num_ability=7,num_arrays=6,reroll=0,best_dice=3,best_ability=6)
alg181=PBE(4,4,add_val=6,num_ability=7,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg182=PBE(4,4,add_val=6,num_ability=7,num_arrays=3,reroll=1,best_dice=3,best_ability=6)
alg183=PBE(4,4,add_val=6,num_ability=7,num_arrays=6,reroll=1,best_dice=3,best_ability=6)
alg184=PBE(4,4,add_val=6,num_ability=7,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg185=PBE(4,4,add_val=6,num_ability=7,num_arrays=3,reroll=2,best_dice=3,best_ability=6)
alg186=PBE(4,4,add_val=6,num_ability=7,num_arrays=6,reroll=2,best_dice=3,best_ability=6)
alg187=PBE(4,4,add_val=6,num_ability=9,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg188=PBE(4,4,add_val=6,num_ability=9,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg189=PBE(4,4,add_val=6,num_ability=9,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg190=PBE(4,4,add_val=6,num_ability=12,num_arrays=1,reroll=0,best_dice=3,best_ability=6)
alg191=PBE(4,4,add_val=6,num_ability=12,num_arrays=1,reroll=1,best_dice=3,best_ability=6)
alg192=PBE(4,4,add_val=6,num_ability=12,num_arrays=1,reroll=2,best_dice=3,best_ability=6)
alg193=PBE(2,8,add_val=2,num_ability=6,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg194=PBE(2,8,add_val=2,num_ability=6,num_arrays=3,reroll=0,best_dice=2,best_ability=6)
alg195=PBE(2,8,add_val=2,num_ability=6,num_arrays=6,reroll=0,best_dice=2,best_ability=6)
alg196=PBE(2,8,add_val=2,num_ability=6,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg197=PBE(2,8,add_val=2,num_ability=6,num_arrays=3,reroll=1,best_dice=2,best_ability=6)
alg198=PBE(2,8,add_val=2,num_ability=6,num_arrays=6,reroll=1,best_dice=2,best_ability=6)
alg199=PBE(2,8,add_val=2,num_ability=6,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg200=PBE(2,8,add_val=2,num_ability=6,num_arrays=3,reroll=2,best_dice=2,best_ability=6)
alg201=PBE(2,8,add_val=2,num_ability=6,num_arrays=6,reroll=2,best_dice=2,best_ability=6)
alg202=PBE(2,8,add_val=2,num_ability=7,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg203=PBE(2,8,add_val=2,num_ability=7,num_arrays=3,reroll=0,best_dice=2,best_ability=6)
alg204=PBE(2,8,add_val=2,num_ability=7,num_arrays=6,reroll=0,best_dice=2,best_ability=6)
alg205=PBE(2,8,add_val=2,num_ability=7,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg206=PBE(2,8,add_val=2,num_ability=7,num_arrays=3,reroll=1,best_dice=2,best_ability=6)
alg207=PBE(2,8,add_val=2,num_ability=7,num_arrays=6,reroll=1,best_dice=2,best_ability=6)
alg208=PBE(2,8,add_val=2,num_ability=7,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg209=PBE(2,8,add_val=2,num_ability=7,num_arrays=3,reroll=2,best_dice=2,best_ability=6)
alg210=PBE(2,8,add_val=2,num_ability=7,num_arrays=6,reroll=2,best_dice=2,best_ability=6)
alg211=PBE(2,8,add_val=2,num_ability=9,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg212=PBE(2,8,add_val=2,num_ability=9,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg213=PBE(2,8,add_val=2,num_ability=9,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg214=PBE(2,8,add_val=2,num_ability=12,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg215=PBE(2,8,add_val=2,num_ability=12,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg216=PBE(2,8,add_val=2,num_ability=12,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg217=PBE(3,8,add_val=2,num_ability=6,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg218=PBE(3,8,add_val=2,num_ability=6,num_arrays=3,reroll=0,best_dice=2,best_ability=6)
alg219=PBE(3,8,add_val=2,num_ability=6,num_arrays=6,reroll=0,best_dice=2,best_ability=6)
alg220=PBE(3,8,add_val=2,num_ability=6,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg221=PBE(3,8,add_val=2,num_ability=6,num_arrays=3,reroll=1,best_dice=2,best_ability=6)
alg222=PBE(3,8,add_val=2,num_ability=6,num_arrays=6,reroll=1,best_dice=2,best_ability=6)
alg223=PBE(3,8,add_val=2,num_ability=6,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg224=PBE(3,8,add_val=2,num_ability=6,num_arrays=3,reroll=2,best_dice=2,best_ability=6)
alg225=PBE(3,8,add_val=2,num_ability=6,num_arrays=6,reroll=2,best_dice=2,best_ability=6)
alg226=PBE(3,8,add_val=2,num_ability=7,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg227=PBE(3,8,add_val=2,num_ability=7,num_arrays=3,reroll=0,best_dice=2,best_ability=6)
alg228=PBE(3,8,add_val=2,num_ability=7,num_arrays=6,reroll=0,best_dice=2,best_ability=6)
alg229=PBE(3,8,add_val=2,num_ability=7,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg230=PBE(3,8,add_val=2,num_ability=7,num_arrays=3,reroll=1,best_dice=2,best_ability=6)
alg231=PBE(3,8,add_val=2,num_ability=7,num_arrays=6,reroll=1,best_dice=2,best_ability=6)
alg232=PBE(3,8,add_val=2,num_ability=7,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg233=PBE(3,8,add_val=2,num_ability=7,num_arrays=3,reroll=2,best_dice=2,best_ability=6)
alg234=PBE(3,8,add_val=2,num_ability=7,num_arrays=6,reroll=2,best_dice=2,best_ability=6)
alg235=PBE(3,8,add_val=2,num_ability=9,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg236=PBE(3,8,add_val=2,num_ability=9,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg237=PBE(3,8,add_val=2,num_ability=9,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg238=PBE(3,8,add_val=2,num_ability=12,num_arrays=1,reroll=0,best_dice=2,best_ability=6)
alg239=PBE(3,8,add_val=2,num_ability=12,num_arrays=1,reroll=1,best_dice=2,best_ability=6)
alg240=PBE(3,8,add_val=2,num_ability=12,num_arrays=1,reroll=2,best_dice=2,best_ability=6)
alg241=PBE(1,10,add_val=8,num_ability=6,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg242=PBE(1,10,add_val=8,num_ability=6,num_arrays=3,reroll=0,best_dice=1,best_ability=6)
alg243=PBE(1,10,add_val=8,num_ability=6,num_arrays=6,reroll=0,best_dice=1,best_ability=6)
alg244=PBE(1,10,add_val=8,num_ability=6,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg245=PBE(1,10,add_val=8,num_ability=6,num_arrays=3,reroll=1,best_dice=1,best_ability=6)
alg246=PBE(1,10,add_val=8,num_ability=6,num_arrays=6,reroll=1,best_dice=1,best_ability=6)
alg247=PBE(1,10,add_val=8,num_ability=6,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg248=PBE(1,10,add_val=8,num_ability=6,num_arrays=3,reroll=2,best_dice=1,best_ability=6)
alg249=PBE(1,10,add_val=8,num_ability=6,num_arrays=6,reroll=2,best_dice=1,best_ability=6)
alg250=PBE(1,10,add_val=8,num_ability=7,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg251=PBE(1,10,add_val=8,num_ability=7,num_arrays=3,reroll=0,best_dice=1,best_ability=6)
alg252=PBE(1,10,add_val=8,num_ability=7,num_arrays=6,reroll=0,best_dice=1,best_ability=6)
alg253=PBE(1,10,add_val=8,num_ability=7,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg254=PBE(1,10,add_val=8,num_ability=7,num_arrays=3,reroll=1,best_dice=1,best_ability=6)
alg255=PBE(1,10,add_val=8,num_ability=7,num_arrays=6,reroll=1,best_dice=1,best_ability=6)
alg256=PBE(1,10,add_val=8,num_ability=7,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg257=PBE(1,10,add_val=8,num_ability=7,num_arrays=3,reroll=2,best_dice=1,best_ability=6)
alg258=PBE(1,10,add_val=8,num_ability=7,num_arrays=6,reroll=2,best_dice=1,best_ability=6)
alg259=PBE(1,10,add_val=8,num_ability=9,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg260=PBE(1,10,add_val=8,num_ability=9,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg261=PBE(1,10,add_val=8,num_ability=9,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg262=PBE(1,10,add_val=8,num_ability=12,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg263=PBE(1,10,add_val=8,num_ability=12,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg264=PBE(1,10,add_val=8,num_ability=12,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg265=PBE(2,10,add_val=8,num_ability=6,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg266=PBE(2,10,add_val=8,num_ability=6,num_arrays=3,reroll=0,best_dice=1,best_ability=6)
alg267=PBE(2,10,add_val=8,num_ability=6,num_arrays=6,reroll=0,best_dice=1,best_ability=6)
alg268=PBE(2,10,add_val=8,num_ability=6,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg269=PBE(2,10,add_val=8,num_ability=6,num_arrays=3,reroll=1,best_dice=1,best_ability=6)
alg270=PBE(2,10,add_val=8,num_ability=6,num_arrays=6,reroll=1,best_dice=1,best_ability=6)
alg271=PBE(2,10,add_val=8,num_ability=6,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg272=PBE(2,10,add_val=8,num_ability=6,num_arrays=3,reroll=2,best_dice=1,best_ability=6)
alg273=PBE(2,10,add_val=8,num_ability=6,num_arrays=6,reroll=2,best_dice=1,best_ability=6)
alg274=PBE(2,10,add_val=8,num_ability=7,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg275=PBE(2,10,add_val=8,num_ability=7,num_arrays=3,reroll=0,best_dice=1,best_ability=6)
alg276=PBE(2,10,add_val=8,num_ability=7,num_arrays=6,reroll=0,best_dice=1,best_ability=6)
alg277=PBE(2,10,add_val=8,num_ability=7,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg278=PBE(2,10,add_val=8,num_ability=7,num_arrays=3,reroll=1,best_dice=1,best_ability=6)
alg279=PBE(2,10,add_val=8,num_ability=7,num_arrays=6,reroll=1,best_dice=1,best_ability=6)
alg280=PBE(2,10,add_val=8,num_ability=7,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg281=PBE(2,10,add_val=8,num_ability=7,num_arrays=3,reroll=2,best_dice=1,best_ability=6)
alg282=PBE(2,10,add_val=8,num_ability=7,num_arrays=6,reroll=2,best_dice=1,best_ability=6)
alg283=PBE(2,10,add_val=8,num_ability=9,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg284=PBE(2,10,add_val=8,num_ability=9,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg285=PBE(2,10,add_val=8,num_ability=9,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg286=PBE(2,10,add_val=8,num_ability=12,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg287=PBE(2,10,add_val=8,num_ability=12,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg288=PBE(2,10,add_val=8,num_ability=12,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg289=PBE(1,12,add_val=6,num_ability=6,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg290=PBE(1,12,add_val=6,num_ability=6,num_arrays=3,reroll=0,best_dice=1,best_ability=6)
alg291=PBE(1,12,add_val=6,num_ability=6,num_arrays=6,reroll=0,best_dice=1,best_ability=6)
alg292=PBE(1,12,add_val=6,num_ability=6,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg293=PBE(1,12,add_val=6,num_ability=6,num_arrays=3,reroll=1,best_dice=1,best_ability=6)
alg294=PBE(1,12,add_val=6,num_ability=6,num_arrays=6,reroll=1,best_dice=1,best_ability=6)
alg295=PBE(1,12,add_val=6,num_ability=6,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg296=PBE(1,12,add_val=6,num_ability=6,num_arrays=3,reroll=2,best_dice=1,best_ability=6)
alg297=PBE(1,12,add_val=6,num_ability=6,num_arrays=6,reroll=2,best_dice=1,best_ability=6)
alg298=PBE(1,12,add_val=6,num_ability=7,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg299=PBE(1,12,add_val=6,num_ability=7,num_arrays=3,reroll=0,best_dice=1,best_ability=6)
alg300=PBE(1,12,add_val=6,num_ability=7,num_arrays=6,reroll=0,best_dice=1,best_ability=6)
alg301=PBE(1,12,add_val=6,num_ability=7,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg302=PBE(1,12,add_val=6,num_ability=7,num_arrays=3,reroll=1,best_dice=1,best_ability=6)
alg303=PBE(1,12,add_val=6,num_ability=7,num_arrays=6,reroll=1,best_dice=1,best_ability=6)
alg304=PBE(1,12,add_val=6,num_ability=7,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg305=PBE(1,12,add_val=6,num_ability=7,num_arrays=3,reroll=2,best_dice=1,best_ability=6)
alg306=PBE(1,12,add_val=6,num_ability=7,num_arrays=6,reroll=2,best_dice=1,best_ability=6)
alg307=PBE(1,12,add_val=6,num_ability=9,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg308=PBE(1,12,add_val=6,num_ability=9,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg309=PBE(1,12,add_val=6,num_ability=9,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg310=PBE(1,12,add_val=6,num_ability=12,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg311=PBE(1,12,add_val=6,num_ability=12,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg312=PBE(1,12,add_val=6,num_ability=12,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg313=PBE(2,12,add_val=6,num_ability=6,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg314=PBE(2,12,add_val=6,num_ability=6,num_arrays=3,reroll=0,best_dice=1,best_ability=6)
alg315=PBE(2,12,add_val=6,num_ability=6,num_arrays=6,reroll=0,best_dice=1,best_ability=6)
alg316=PBE(2,12,add_val=6,num_ability=6,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg317=PBE(2,12,add_val=6,num_ability=6,num_arrays=3,reroll=1,best_dice=1,best_ability=6)
alg318=PBE(2,12,add_val=6,num_ability=6,num_arrays=6,reroll=1,best_dice=1,best_ability=6)
alg319=PBE(2,12,add_val=6,num_ability=6,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg320=PBE(2,12,add_val=6,num_ability=6,num_arrays=3,reroll=2,best_dice=1,best_ability=6)
alg321=PBE(2,12,add_val=6,num_ability=6,num_arrays=6,reroll=2,best_dice=1,best_ability=6)
alg322=PBE(2,12,add_val=6,num_ability=7,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg323=PBE(2,12,add_val=6,num_ability=7,num_arrays=3,reroll=0,best_dice=1,best_ability=6)
alg324=PBE(2,12,add_val=6,num_ability=7,num_arrays=6,reroll=0,best_dice=1,best_ability=6)
alg325=PBE(2,12,add_val=6,num_ability=7,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg326=PBE(2,12,add_val=6,num_ability=7,num_arrays=3,reroll=1,best_dice=1,best_ability=6)
alg327=PBE(2,12,add_val=6,num_ability=7,num_arrays=6,reroll=1,best_dice=1,best_ability=6)
alg328=PBE(2,12,add_val=6,num_ability=7,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg329=PBE(2,12,add_val=6,num_ability=7,num_arrays=3,reroll=2,best_dice=1,best_ability=6)
alg330=PBE(2,12,add_val=6,num_ability=7,num_arrays=6,reroll=2,best_dice=1,best_ability=6)
alg331=PBE(2,12,add_val=6,num_ability=9,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg332=PBE(2,12,add_val=6,num_ability=9,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg333=PBE(2,12,add_val=6,num_ability=9,num_arrays=1,reroll=2,best_dice=1,best_ability=6)
alg334=PBE(2,12,add_val=6,num_ability=12,num_arrays=1,reroll=0,best_dice=1,best_ability=6)
alg335=PBE(2,12,add_val=6,num_ability=12,num_arrays=1,reroll=1,best_dice=1,best_ability=6)
alg336=PBE(2,12,add_val=6,num_ability=12,num_arrays=1,reroll=2,best_dice=1,best_ability=6)

# %%
# %matplotlib inline
res = []
res.append(['Description','Typical Array','Mean','Std','5%','95%'])
res.append(alg1.roll_mc().plot_histogram(title_prefix='1.').get_results(title_prefix='1.'))
res.append(alg2.roll_mc().plot_histogram(title_prefix='2.').get_results(title_prefix='2.'))
res.append(alg3.roll_mc().plot_histogram(title_prefix='3.').get_results(title_prefix='3.'))
res.append(alg4.roll_mc().plot_histogram(title_prefix='4.').get_results(title_prefix='4.'))
res.append(alg5.roll_mc().plot_histogram(title_prefix='5.').get_results(title_prefix='5.'))
res.append(alg6.roll_mc().plot_histogram(title_prefix='6.').get_results(title_prefix='6.'))
res.append(alg7.roll_mc().plot_histogram(title_prefix='7.').get_results(title_prefix='7.'))
res.append(alg8.roll_mc().plot_histogram(title_prefix='8.').get_results(title_prefix='8.'))
res.append(alg9.roll_mc().plot_histogram(title_prefix='9.').get_results(title_prefix='9.'))
res.append(alg10.roll_mc().plot_histogram(title_prefix='10.').get_results(title_prefix='10.'))
res.append(alg11.roll_mc().plot_histogram(title_prefix='11.').get_results(title_prefix='11.'))
res.append(alg12.roll_mc().plot_histogram(title_prefix='12.').get_results(title_prefix='12.'))
res.append(alg13.roll_mc().plot_histogram(title_prefix='13.').get_results(title_prefix='13.'))
res.append(alg14.roll_mc().plot_histogram(title_prefix='14.').get_results(title_prefix='14.'))
res.append(alg15.roll_mc().plot_histogram(title_prefix='15.').get_results(title_prefix='15.'))
res.append(alg16.roll_mc().plot_histogram(title_prefix='16.').get_results(title_prefix='16.'))
res.append(alg17.roll_mc().plot_histogram(title_prefix='17.').get_results(title_prefix='17.'))
res.append(alg18.roll_mc().plot_histogram(title_prefix='18.').get_results(title_prefix='18.'))
res.append(alg19.roll_mc().plot_histogram(title_prefix='19.').get_results(title_prefix='19.'))
res.append(alg20.roll_mc().plot_histogram(title_prefix='20.').get_results(title_prefix='20.'))
res.append(alg21.roll_mc().plot_histogram(title_prefix='21.').get_results(title_prefix='21.'))
res.append(alg22.roll_mc().plot_histogram(title_prefix='22.').get_results(title_prefix='22.'))
res.append(alg23.roll_mc().plot_histogram(title_prefix='23.').get_results(title_prefix='23.'))
res.append(alg24.roll_mc().plot_histogram(title_prefix='24.').get_results(title_prefix='24.'))
res.append(alg25.roll_mc().plot_histogram(title_prefix='25.').get_results(title_prefix='25.'))
res.append(alg26.roll_mc().plot_histogram(title_prefix='26.').get_results(title_prefix='26.'))
res.append(alg27.roll_mc().plot_histogram(title_prefix='27.').get_results(title_prefix='27.'))
res.append(alg28.roll_mc().plot_histogram(title_prefix='28.').get_results(title_prefix='28.'))
res.append(alg29.roll_mc().plot_histogram(title_prefix='29.').get_results(title_prefix='29.'))
res.append(alg30.roll_mc().plot_histogram(title_prefix='30.').get_results(title_prefix='30.'))
res.append(alg31.roll_mc().plot_histogram(title_prefix='31.').get_results(title_prefix='31.'))
res.append(alg32.roll_mc().plot_histogram(title_prefix='32.').get_results(title_prefix='32.'))
res.append(alg33.roll_mc().plot_histogram(title_prefix='33.').get_results(title_prefix='33.'))
res.append(alg34.roll_mc().plot_histogram(title_prefix='34.').get_results(title_prefix='34.'))
res.append(alg35.roll_mc().plot_histogram(title_prefix='35.').get_results(title_prefix='35.'))
res.append(alg36.roll_mc().plot_histogram(title_prefix='36.').get_results(title_prefix='36.'))
res.append(alg37.roll_mc().plot_histogram(title_prefix='37.').get_results(title_prefix='37.'))
res.append(alg38.roll_mc().plot_histogram(title_prefix='38.').get_results(title_prefix='38.'))
res.append(alg39.roll_mc().plot_histogram(title_prefix='39.').get_results(title_prefix='39.'))
res.append(alg40.roll_mc().plot_histogram(title_prefix='40.').get_results(title_prefix='40.'))
res.append(alg41.roll_mc().plot_histogram(title_prefix='41.').get_results(title_prefix='41.'))
res.append(alg42.roll_mc().plot_histogram(title_prefix='42.').get_results(title_prefix='42.'))
res.append(alg43.roll_mc().plot_histogram(title_prefix='43.').get_results(title_prefix='43.'))
res.append(alg44.roll_mc().plot_histogram(title_prefix='44.').get_results(title_prefix='44.'))
res.append(alg45.roll_mc().plot_histogram(title_prefix='45.').get_results(title_prefix='45.'))
res.append(alg46.roll_mc().plot_histogram(title_prefix='46.').get_results(title_prefix='46.'))
res.append(alg47.roll_mc().plot_histogram(title_prefix='47.').get_results(title_prefix='47.'))
res.append(alg48.roll_mc().plot_histogram(title_prefix='48.').get_results(title_prefix='48.'))
res.append(alg49.roll_mc().plot_histogram(title_prefix='49.').get_results(title_prefix='49.'))
res.append(alg50.roll_mc().plot_histogram(title_prefix='50.').get_results(title_prefix='50.'))
res.append(alg51.roll_mc().plot_histogram(title_prefix='51.').get_results(title_prefix='51.'))
res.append(alg52.roll_mc().plot_histogram(title_prefix='52.').get_results(title_prefix='52.'))
res.append(alg53.roll_mc().plot_histogram(title_prefix='53.').get_results(title_prefix='53.'))
res.append(alg54.roll_mc().plot_histogram(title_prefix='54.').get_results(title_prefix='54.'))
res.append(alg55.roll_mc().plot_histogram(title_prefix='55.').get_results(title_prefix='55.'))
res.append(alg56.roll_mc().plot_histogram(title_prefix='56.').get_results(title_prefix='56.'))
res.append(alg57.roll_mc().plot_histogram(title_prefix='57.').get_results(title_prefix='57.'))
res.append(alg58.roll_mc().plot_histogram(title_prefix='58.').get_results(title_prefix='58.'))
res.append(alg59.roll_mc().plot_histogram(title_prefix='59.').get_results(title_prefix='59.'))
res.append(alg60.roll_mc().plot_histogram(title_prefix='60.').get_results(title_prefix='60.'))
res.append(alg61.roll_mc().plot_histogram(title_prefix='61.').get_results(title_prefix='61.'))
res.append(alg62.roll_mc().plot_histogram(title_prefix='62.').get_results(title_prefix='62.'))
res.append(alg63.roll_mc().plot_histogram(title_prefix='63.').get_results(title_prefix='63.'))
res.append(alg64.roll_mc().plot_histogram(title_prefix='64.').get_results(title_prefix='64.'))
res.append(alg65.roll_mc().plot_histogram(title_prefix='65.').get_results(title_prefix='65.'))
res.append(alg66.roll_mc().plot_histogram(title_prefix='66.').get_results(title_prefix='66.'))
res.append(alg67.roll_mc().plot_histogram(title_prefix='67.').get_results(title_prefix='67.'))
res.append(alg68.roll_mc().plot_histogram(title_prefix='68.').get_results(title_prefix='68.'))
res.append(alg69.roll_mc().plot_histogram(title_prefix='69.').get_results(title_prefix='69.'))
res.append(alg70.roll_mc().plot_histogram(title_prefix='70.').get_results(title_prefix='70.'))
res.append(alg71.roll_mc().plot_histogram(title_prefix='71.').get_results(title_prefix='71.'))
res.append(alg72.roll_mc().plot_histogram(title_prefix='72.').get_results(title_prefix='72.'))
res.append(alg73.roll_mc().plot_histogram(title_prefix='73.').get_results(title_prefix='73.'))
res.append(alg74.roll_mc().plot_histogram(title_prefix='74.').get_results(title_prefix='74.'))
res.append(alg75.roll_mc().plot_histogram(title_prefix='75.').get_results(title_prefix='75.'))
res.append(alg76.roll_mc().plot_histogram(title_prefix='76.').get_results(title_prefix='76.'))
res.append(alg77.roll_mc().plot_histogram(title_prefix='77.').get_results(title_prefix='77.'))
res.append(alg78.roll_mc().plot_histogram(title_prefix='78.').get_results(title_prefix='78.'))
res.append(alg79.roll_mc().plot_histogram(title_prefix='79.').get_results(title_prefix='79.'))
res.append(alg80.roll_mc().plot_histogram(title_prefix='80.').get_results(title_prefix='80.'))
res.append(alg81.roll_mc().plot_histogram(title_prefix='81.').get_results(title_prefix='81.'))
res.append(alg82.roll_mc().plot_histogram(title_prefix='82.').get_results(title_prefix='82.'))
res.append(alg83.roll_mc().plot_histogram(title_prefix='83.').get_results(title_prefix='83.'))
res.append(alg84.roll_mc().plot_histogram(title_prefix='84.').get_results(title_prefix='84.'))
res.append(alg85.roll_mc().plot_histogram(title_prefix='85.').get_results(title_prefix='85.'))
res.append(alg86.roll_mc().plot_histogram(title_prefix='86.').get_results(title_prefix='86.'))
res.append(alg87.roll_mc().plot_histogram(title_prefix='87.').get_results(title_prefix='87.'))
res.append(alg88.roll_mc().plot_histogram(title_prefix='88.').get_results(title_prefix='88.'))
res.append(alg89.roll_mc().plot_histogram(title_prefix='89.').get_results(title_prefix='89.'))
res.append(alg90.roll_mc().plot_histogram(title_prefix='90.').get_results(title_prefix='90.'))
res.append(alg91.roll_mc().plot_histogram(title_prefix='91.').get_results(title_prefix='91.'))
res.append(alg92.roll_mc().plot_histogram(title_prefix='92.').get_results(title_prefix='92.'))
res.append(alg93.roll_mc().plot_histogram(title_prefix='93.').get_results(title_prefix='93.'))
res.append(alg94.roll_mc().plot_histogram(title_prefix='94.').get_results(title_prefix='94.'))
res.append(alg95.roll_mc().plot_histogram(title_prefix='95.').get_results(title_prefix='95.'))
res.append(alg96.roll_mc().plot_histogram(title_prefix='96.').get_results(title_prefix='96.'))
res.append(alg97.roll_mc().plot_histogram(title_prefix='97.').get_results(title_prefix='97.'))
res.append(alg98.roll_mc().plot_histogram(title_prefix='98.').get_results(title_prefix='98.'))
res.append(alg99.roll_mc().plot_histogram(title_prefix='99.').get_results(title_prefix='99.'))
res.append(alg100.roll_mc().plot_histogram(title_prefix='100.').get_results(title_prefix='100.'))
res.append(alg101.roll_mc().plot_histogram(title_prefix='101.').get_results(title_prefix='101.'))
res.append(alg102.roll_mc().plot_histogram(title_prefix='102.').get_results(title_prefix='102.'))
res.append(alg103.roll_mc().plot_histogram(title_prefix='103.').get_results(title_prefix='103.'))
res.append(alg104.roll_mc().plot_histogram(title_prefix='104.').get_results(title_prefix='104.'))
res.append(alg105.roll_mc().plot_histogram(title_prefix='105.').get_results(title_prefix='105.'))
res.append(alg106.roll_mc().plot_histogram(title_prefix='106.').get_results(title_prefix='106.'))
res.append(alg107.roll_mc().plot_histogram(title_prefix='107.').get_results(title_prefix='107.'))
res.append(alg108.roll_mc().plot_histogram(title_prefix='108.').get_results(title_prefix='108.'))
res.append(alg109.roll_mc().plot_histogram(title_prefix='109.').get_results(title_prefix='109.'))
res.append(alg110.roll_mc().plot_histogram(title_prefix='110.').get_results(title_prefix='110.'))
res.append(alg111.roll_mc().plot_histogram(title_prefix='111.').get_results(title_prefix='111.'))
res.append(alg112.roll_mc().plot_histogram(title_prefix='112.').get_results(title_prefix='112.'))
res.append(alg113.roll_mc().plot_histogram(title_prefix='113.').get_results(title_prefix='113.'))
res.append(alg114.roll_mc().plot_histogram(title_prefix='114.').get_results(title_prefix='114.'))
res.append(alg115.roll_mc().plot_histogram(title_prefix='115.').get_results(title_prefix='115.'))
res.append(alg116.roll_mc().plot_histogram(title_prefix='116.').get_results(title_prefix='116.'))
res.append(alg117.roll_mc().plot_histogram(title_prefix='117.').get_results(title_prefix='117.'))
res.append(alg118.roll_mc().plot_histogram(title_prefix='118.').get_results(title_prefix='118.'))
res.append(alg119.roll_mc().plot_histogram(title_prefix='119.').get_results(title_prefix='119.'))
res.append(alg120.roll_mc().plot_histogram(title_prefix='120.').get_results(title_prefix='120.'))
res.append(alg121.roll_mc().plot_histogram(title_prefix='121.').get_results(title_prefix='121.'))
res.append(alg122.roll_mc().plot_histogram(title_prefix='122.').get_results(title_prefix='122.'))
res.append(alg123.roll_mc().plot_histogram(title_prefix='123.').get_results(title_prefix='123.'))
res.append(alg124.roll_mc().plot_histogram(title_prefix='124.').get_results(title_prefix='124.'))
res.append(alg125.roll_mc().plot_histogram(title_prefix='125.').get_results(title_prefix='125.'))
res.append(alg126.roll_mc().plot_histogram(title_prefix='126.').get_results(title_prefix='126.'))
res.append(alg127.roll_mc().plot_histogram(title_prefix='127.').get_results(title_prefix='127.'))
res.append(alg128.roll_mc().plot_histogram(title_prefix='128.').get_results(title_prefix='128.'))
res.append(alg129.roll_mc().plot_histogram(title_prefix='129.').get_results(title_prefix='129.'))
res.append(alg130.roll_mc().plot_histogram(title_prefix='130.').get_results(title_prefix='130.'))
res.append(alg131.roll_mc().plot_histogram(title_prefix='131.').get_results(title_prefix='131.'))
res.append(alg132.roll_mc().plot_histogram(title_prefix='132.').get_results(title_prefix='132.'))
res.append(alg133.roll_mc().plot_histogram(title_prefix='133.').get_results(title_prefix='133.'))
res.append(alg134.roll_mc().plot_histogram(title_prefix='134.').get_results(title_prefix='134.'))
res.append(alg135.roll_mc().plot_histogram(title_prefix='135.').get_results(title_prefix='135.'))
res.append(alg136.roll_mc().plot_histogram(title_prefix='136.').get_results(title_prefix='136.'))
res.append(alg137.roll_mc().plot_histogram(title_prefix='137.').get_results(title_prefix='137.'))
res.append(alg138.roll_mc().plot_histogram(title_prefix='138.').get_results(title_prefix='138.'))
res.append(alg139.roll_mc().plot_histogram(title_prefix='139.').get_results(title_prefix='139.'))
res.append(alg140.roll_mc().plot_histogram(title_prefix='140.').get_results(title_prefix='140.'))
res.append(alg141.roll_mc().plot_histogram(title_prefix='141.').get_results(title_prefix='141.'))
res.append(alg142.roll_mc().plot_histogram(title_prefix='142.').get_results(title_prefix='142.'))
res.append(alg143.roll_mc().plot_histogram(title_prefix='143.').get_results(title_prefix='143.'))
res.append(alg144.roll_mc().plot_histogram(title_prefix='144.').get_results(title_prefix='144.'))
res.append(alg145.roll_mc().plot_histogram(title_prefix='145.').get_results(title_prefix='145.'))
res.append(alg146.roll_mc().plot_histogram(title_prefix='146.').get_results(title_prefix='146.'))
res.append(alg147.roll_mc().plot_histogram(title_prefix='147.').get_results(title_prefix='147.'))
res.append(alg148.roll_mc().plot_histogram(title_prefix='148.').get_results(title_prefix='148.'))
res.append(alg149.roll_mc().plot_histogram(title_prefix='149.').get_results(title_prefix='149.'))
res.append(alg150.roll_mc().plot_histogram(title_prefix='150.').get_results(title_prefix='150.'))
res.append(alg151.roll_mc().plot_histogram(title_prefix='151.').get_results(title_prefix='151.'))
res.append(alg152.roll_mc().plot_histogram(title_prefix='152.').get_results(title_prefix='152.'))
res.append(alg153.roll_mc().plot_histogram(title_prefix='153.').get_results(title_prefix='153.'))
res.append(alg154.roll_mc().plot_histogram(title_prefix='154.').get_results(title_prefix='154.'))
res.append(alg155.roll_mc().plot_histogram(title_prefix='155.').get_results(title_prefix='155.'))
res.append(alg156.roll_mc().plot_histogram(title_prefix='156.').get_results(title_prefix='156.'))
res.append(alg157.roll_mc().plot_histogram(title_prefix='157.').get_results(title_prefix='157.'))
res.append(alg158.roll_mc().plot_histogram(title_prefix='158.').get_results(title_prefix='158.'))
res.append(alg159.roll_mc().plot_histogram(title_prefix='159.').get_results(title_prefix='159.'))
res.append(alg160.roll_mc().plot_histogram(title_prefix='160.').get_results(title_prefix='160.'))
res.append(alg161.roll_mc().plot_histogram(title_prefix='161.').get_results(title_prefix='161.'))
res.append(alg162.roll_mc().plot_histogram(title_prefix='162.').get_results(title_prefix='162.'))
res.append(alg163.roll_mc().plot_histogram(title_prefix='163.').get_results(title_prefix='163.'))
res.append(alg164.roll_mc().plot_histogram(title_prefix='164.').get_results(title_prefix='164.'))
res.append(alg165.roll_mc().plot_histogram(title_prefix='165.').get_results(title_prefix='165.'))
res.append(alg166.roll_mc().plot_histogram(title_prefix='166.').get_results(title_prefix='166.'))
res.append(alg167.roll_mc().plot_histogram(title_prefix='167.').get_results(title_prefix='167.'))
res.append(alg168.roll_mc().plot_histogram(title_prefix='168.').get_results(title_prefix='168.'))
res.append(alg169.roll_mc().plot_histogram(title_prefix='169.').get_results(title_prefix='169.'))
res.append(alg170.roll_mc().plot_histogram(title_prefix='170.').get_results(title_prefix='170.'))
res.append(alg171.roll_mc().plot_histogram(title_prefix='171.').get_results(title_prefix='171.'))
res.append(alg172.roll_mc().plot_histogram(title_prefix='172.').get_results(title_prefix='172.'))
res.append(alg173.roll_mc().plot_histogram(title_prefix='173.').get_results(title_prefix='173.'))
res.append(alg174.roll_mc().plot_histogram(title_prefix='174.').get_results(title_prefix='174.'))
res.append(alg175.roll_mc().plot_histogram(title_prefix='175.').get_results(title_prefix='175.'))
res.append(alg176.roll_mc().plot_histogram(title_prefix='176.').get_results(title_prefix='176.'))
res.append(alg177.roll_mc().plot_histogram(title_prefix='177.').get_results(title_prefix='177.'))
res.append(alg178.roll_mc().plot_histogram(title_prefix='178.').get_results(title_prefix='178.'))
res.append(alg179.roll_mc().plot_histogram(title_prefix='179.').get_results(title_prefix='179.'))
res.append(alg180.roll_mc().plot_histogram(title_prefix='180.').get_results(title_prefix='180.'))
res.append(alg181.roll_mc().plot_histogram(title_prefix='181.').get_results(title_prefix='181.'))
res.append(alg182.roll_mc().plot_histogram(title_prefix='182.').get_results(title_prefix='182.'))
res.append(alg183.roll_mc().plot_histogram(title_prefix='183.').get_results(title_prefix='183.'))
res.append(alg184.roll_mc().plot_histogram(title_prefix='184.').get_results(title_prefix='184.'))
res.append(alg185.roll_mc().plot_histogram(title_prefix='185.').get_results(title_prefix='185.'))
res.append(alg186.roll_mc().plot_histogram(title_prefix='186.').get_results(title_prefix='186.'))
res.append(alg187.roll_mc().plot_histogram(title_prefix='187.').get_results(title_prefix='187.'))
res.append(alg188.roll_mc().plot_histogram(title_prefix='188.').get_results(title_prefix='188.'))
res.append(alg189.roll_mc().plot_histogram(title_prefix='189.').get_results(title_prefix='189.'))
res.append(alg190.roll_mc().plot_histogram(title_prefix='190.').get_results(title_prefix='190.'))
res.append(alg191.roll_mc().plot_histogram(title_prefix='191.').get_results(title_prefix='191.'))
res.append(alg192.roll_mc().plot_histogram(title_prefix='192.').get_results(title_prefix='192.'))
res.append(alg193.roll_mc().plot_histogram(title_prefix='193.').get_results(title_prefix='193.'))
res.append(alg194.roll_mc().plot_histogram(title_prefix='194.').get_results(title_prefix='194.'))
res.append(alg195.roll_mc().plot_histogram(title_prefix='195.').get_results(title_prefix='195.'))
res.append(alg196.roll_mc().plot_histogram(title_prefix='196.').get_results(title_prefix='196.'))
res.append(alg197.roll_mc().plot_histogram(title_prefix='197.').get_results(title_prefix='197.'))
res.append(alg198.roll_mc().plot_histogram(title_prefix='198.').get_results(title_prefix='198.'))
res.append(alg199.roll_mc().plot_histogram(title_prefix='199.').get_results(title_prefix='199.'))
res.append(alg200.roll_mc().plot_histogram(title_prefix='200.').get_results(title_prefix='200.'))
res.append(alg201.roll_mc().plot_histogram(title_prefix='201.').get_results(title_prefix='201.'))
res.append(alg202.roll_mc().plot_histogram(title_prefix='202.').get_results(title_prefix='202.'))
res.append(alg203.roll_mc().plot_histogram(title_prefix='203.').get_results(title_prefix='203.'))
res.append(alg204.roll_mc().plot_histogram(title_prefix='204.').get_results(title_prefix='204.'))
res.append(alg205.roll_mc().plot_histogram(title_prefix='205.').get_results(title_prefix='205.'))
res.append(alg206.roll_mc().plot_histogram(title_prefix='206.').get_results(title_prefix='206.'))
res.append(alg207.roll_mc().plot_histogram(title_prefix='207.').get_results(title_prefix='207.'))
res.append(alg208.roll_mc().plot_histogram(title_prefix='208.').get_results(title_prefix='208.'))
res.append(alg209.roll_mc().plot_histogram(title_prefix='209.').get_results(title_prefix='209.'))
res.append(alg210.roll_mc().plot_histogram(title_prefix='210.').get_results(title_prefix='210.'))
res.append(alg211.roll_mc().plot_histogram(title_prefix='211.').get_results(title_prefix='211.'))
res.append(alg212.roll_mc().plot_histogram(title_prefix='212.').get_results(title_prefix='212.'))
res.append(alg213.roll_mc().plot_histogram(title_prefix='213.').get_results(title_prefix='213.'))
res.append(alg214.roll_mc().plot_histogram(title_prefix='214.').get_results(title_prefix='214.'))
res.append(alg215.roll_mc().plot_histogram(title_prefix='215.').get_results(title_prefix='215.'))
res.append(alg216.roll_mc().plot_histogram(title_prefix='216.').get_results(title_prefix='216.'))
res.append(alg217.roll_mc().plot_histogram(title_prefix='217.').get_results(title_prefix='217.'))
res.append(alg218.roll_mc().plot_histogram(title_prefix='218.').get_results(title_prefix='218.'))
res.append(alg219.roll_mc().plot_histogram(title_prefix='219.').get_results(title_prefix='219.'))
res.append(alg220.roll_mc().plot_histogram(title_prefix='220.').get_results(title_prefix='220.'))
res.append(alg221.roll_mc().plot_histogram(title_prefix='221.').get_results(title_prefix='221.'))
res.append(alg222.roll_mc().plot_histogram(title_prefix='222.').get_results(title_prefix='222.'))
res.append(alg223.roll_mc().plot_histogram(title_prefix='223.').get_results(title_prefix='223.'))
res.append(alg224.roll_mc().plot_histogram(title_prefix='224.').get_results(title_prefix='224.'))
res.append(alg225.roll_mc().plot_histogram(title_prefix='225.').get_results(title_prefix='225.'))
res.append(alg226.roll_mc().plot_histogram(title_prefix='226.').get_results(title_prefix='226.'))
res.append(alg227.roll_mc().plot_histogram(title_prefix='227.').get_results(title_prefix='227.'))
res.append(alg228.roll_mc().plot_histogram(title_prefix='228.').get_results(title_prefix='228.'))
res.append(alg229.roll_mc().plot_histogram(title_prefix='229.').get_results(title_prefix='229.'))
res.append(alg230.roll_mc().plot_histogram(title_prefix='230.').get_results(title_prefix='230.'))
res.append(alg231.roll_mc().plot_histogram(title_prefix='231.').get_results(title_prefix='231.'))
res.append(alg232.roll_mc().plot_histogram(title_prefix='232.').get_results(title_prefix='232.'))
res.append(alg233.roll_mc().plot_histogram(title_prefix='233.').get_results(title_prefix='233.'))
res.append(alg234.roll_mc().plot_histogram(title_prefix='234.').get_results(title_prefix='234.'))
res.append(alg235.roll_mc().plot_histogram(title_prefix='235.').get_results(title_prefix='235.'))
res.append(alg236.roll_mc().plot_histogram(title_prefix='236.').get_results(title_prefix='236.'))
res.append(alg237.roll_mc().plot_histogram(title_prefix='237.').get_results(title_prefix='237.'))
res.append(alg238.roll_mc().plot_histogram(title_prefix='238.').get_results(title_prefix='238.'))
res.append(alg239.roll_mc().plot_histogram(title_prefix='239.').get_results(title_prefix='239.'))
res.append(alg240.roll_mc().plot_histogram(title_prefix='240.').get_results(title_prefix='240.'))
res.append(alg241.roll_mc().plot_histogram(title_prefix='241.').get_results(title_prefix='241.'))
res.append(alg242.roll_mc().plot_histogram(title_prefix='242.').get_results(title_prefix='242.'))
res.append(alg243.roll_mc().plot_histogram(title_prefix='243.').get_results(title_prefix='243.'))
res.append(alg244.roll_mc().plot_histogram(title_prefix='244.').get_results(title_prefix='244.'))
res.append(alg245.roll_mc().plot_histogram(title_prefix='245.').get_results(title_prefix='245.'))
res.append(alg246.roll_mc().plot_histogram(title_prefix='246.').get_results(title_prefix='246.'))
res.append(alg247.roll_mc().plot_histogram(title_prefix='247.').get_results(title_prefix='247.'))
res.append(alg248.roll_mc().plot_histogram(title_prefix='248.').get_results(title_prefix='248.'))
res.append(alg249.roll_mc().plot_histogram(title_prefix='249.').get_results(title_prefix='249.'))
res.append(alg250.roll_mc().plot_histogram(title_prefix='250.').get_results(title_prefix='250.'))
res.append(alg251.roll_mc().plot_histogram(title_prefix='251.').get_results(title_prefix='251.'))
res.append(alg252.roll_mc().plot_histogram(title_prefix='252.').get_results(title_prefix='252.'))
res.append(alg253.roll_mc().plot_histogram(title_prefix='253.').get_results(title_prefix='253.'))
res.append(alg254.roll_mc().plot_histogram(title_prefix='254.').get_results(title_prefix='254.'))
res.append(alg255.roll_mc().plot_histogram(title_prefix='255.').get_results(title_prefix='255.'))
res.append(alg256.roll_mc().plot_histogram(title_prefix='256.').get_results(title_prefix='256.'))
res.append(alg257.roll_mc().plot_histogram(title_prefix='257.').get_results(title_prefix='257.'))
res.append(alg258.roll_mc().plot_histogram(title_prefix='258.').get_results(title_prefix='258.'))
res.append(alg259.roll_mc().plot_histogram(title_prefix='259.').get_results(title_prefix='259.'))
res.append(alg260.roll_mc().plot_histogram(title_prefix='260.').get_results(title_prefix='260.'))
res.append(alg261.roll_mc().plot_histogram(title_prefix='261.').get_results(title_prefix='261.'))
res.append(alg262.roll_mc().plot_histogram(title_prefix='262.').get_results(title_prefix='262.'))
res.append(alg263.roll_mc().plot_histogram(title_prefix='263.').get_results(title_prefix='263.'))
res.append(alg264.roll_mc().plot_histogram(title_prefix='264.').get_results(title_prefix='264.'))
res.append(alg265.roll_mc().plot_histogram(title_prefix='265.').get_results(title_prefix='265.'))
res.append(alg266.roll_mc().plot_histogram(title_prefix='266.').get_results(title_prefix='266.'))
res.append(alg267.roll_mc().plot_histogram(title_prefix='267.').get_results(title_prefix='267.'))
res.append(alg268.roll_mc().plot_histogram(title_prefix='268.').get_results(title_prefix='268.'))
res.append(alg269.roll_mc().plot_histogram(title_prefix='269.').get_results(title_prefix='269.'))
res.append(alg270.roll_mc().plot_histogram(title_prefix='270.').get_results(title_prefix='270.'))
res.append(alg271.roll_mc().plot_histogram(title_prefix='271.').get_results(title_prefix='271.'))
res.append(alg272.roll_mc().plot_histogram(title_prefix='272.').get_results(title_prefix='272.'))
res.append(alg273.roll_mc().plot_histogram(title_prefix='273.').get_results(title_prefix='273.'))
res.append(alg274.roll_mc().plot_histogram(title_prefix='274.').get_results(title_prefix='274.'))
res.append(alg275.roll_mc().plot_histogram(title_prefix='275.').get_results(title_prefix='275.'))
res.append(alg276.roll_mc().plot_histogram(title_prefix='276.').get_results(title_prefix='276.'))
res.append(alg277.roll_mc().plot_histogram(title_prefix='277.').get_results(title_prefix='277.'))
res.append(alg278.roll_mc().plot_histogram(title_prefix='278.').get_results(title_prefix='278.'))
res.append(alg279.roll_mc().plot_histogram(title_prefix='279.').get_results(title_prefix='279.'))
res.append(alg280.roll_mc().plot_histogram(title_prefix='280.').get_results(title_prefix='280.'))
res.append(alg281.roll_mc().plot_histogram(title_prefix='281.').get_results(title_prefix='281.'))
res.append(alg282.roll_mc().plot_histogram(title_prefix='282.').get_results(title_prefix='282.'))
res.append(alg283.roll_mc().plot_histogram(title_prefix='283.').get_results(title_prefix='283.'))
res.append(alg284.roll_mc().plot_histogram(title_prefix='284.').get_results(title_prefix='284.'))
res.append(alg285.roll_mc().plot_histogram(title_prefix='285.').get_results(title_prefix='285.'))
res.append(alg286.roll_mc().plot_histogram(title_prefix='286.').get_results(title_prefix='286.'))
res.append(alg287.roll_mc().plot_histogram(title_prefix='287.').get_results(title_prefix='287.'))
res.append(alg288.roll_mc().plot_histogram(title_prefix='288.').get_results(title_prefix='288.'))
res.append(alg289.roll_mc().plot_histogram(title_prefix='289.').get_results(title_prefix='289.'))
res.append(alg290.roll_mc().plot_histogram(title_prefix='290.').get_results(title_prefix='290.'))
res.append(alg291.roll_mc().plot_histogram(title_prefix='291.').get_results(title_prefix='291.'))
res.append(alg292.roll_mc().plot_histogram(title_prefix='292.').get_results(title_prefix='292.'))
res.append(alg293.roll_mc().plot_histogram(title_prefix='293.').get_results(title_prefix='293.'))
res.append(alg294.roll_mc().plot_histogram(title_prefix='294.').get_results(title_prefix='294.'))
res.append(alg295.roll_mc().plot_histogram(title_prefix='295.').get_results(title_prefix='295.'))
res.append(alg296.roll_mc().plot_histogram(title_prefix='296.').get_results(title_prefix='296.'))
res.append(alg297.roll_mc().plot_histogram(title_prefix='297.').get_results(title_prefix='297.'))
res.append(alg298.roll_mc().plot_histogram(title_prefix='298.').get_results(title_prefix='298.'))
res.append(alg299.roll_mc().plot_histogram(title_prefix='299.').get_results(title_prefix='299.'))
res.append(alg300.roll_mc().plot_histogram(title_prefix='300.').get_results(title_prefix='300.'))
res.append(alg301.roll_mc().plot_histogram(title_prefix='301.').get_results(title_prefix='301.'))
res.append(alg302.roll_mc().plot_histogram(title_prefix='302.').get_results(title_prefix='302.'))
res.append(alg303.roll_mc().plot_histogram(title_prefix='303.').get_results(title_prefix='303.'))
res.append(alg304.roll_mc().plot_histogram(title_prefix='304.').get_results(title_prefix='304.'))
res.append(alg305.roll_mc().plot_histogram(title_prefix='305.').get_results(title_prefix='305.'))
res.append(alg306.roll_mc().plot_histogram(title_prefix='306.').get_results(title_prefix='306.'))
res.append(alg307.roll_mc().plot_histogram(title_prefix='307.').get_results(title_prefix='307.'))
res.append(alg308.roll_mc().plot_histogram(title_prefix='308.').get_results(title_prefix='308.'))
res.append(alg309.roll_mc().plot_histogram(title_prefix='309.').get_results(title_prefix='309.'))
res.append(alg310.roll_mc().plot_histogram(title_prefix='310.').get_results(title_prefix='310.'))
res.append(alg311.roll_mc().plot_histogram(title_prefix='311.').get_results(title_prefix='311.'))
res.append(alg312.roll_mc().plot_histogram(title_prefix='312.').get_results(title_prefix='312.'))
res.append(alg313.roll_mc().plot_histogram(title_prefix='313.').get_results(title_prefix='313.'))
res.append(alg314.roll_mc().plot_histogram(title_prefix='314.').get_results(title_prefix='314.'))
res.append(alg315.roll_mc().plot_histogram(title_prefix='315.').get_results(title_prefix='315.'))
res.append(alg316.roll_mc().plot_histogram(title_prefix='316.').get_results(title_prefix='316.'))
res.append(alg317.roll_mc().plot_histogram(title_prefix='317.').get_results(title_prefix='317.'))
res.append(alg318.roll_mc().plot_histogram(title_prefix='318.').get_results(title_prefix='318.'))
res.append(alg319.roll_mc().plot_histogram(title_prefix='319.').get_results(title_prefix='319.'))
res.append(alg320.roll_mc().plot_histogram(title_prefix='320.').get_results(title_prefix='320.'))
res.append(alg321.roll_mc().plot_histogram(title_prefix='321.').get_results(title_prefix='321.'))
res.append(alg322.roll_mc().plot_histogram(title_prefix='322.').get_results(title_prefix='322.'))
res.append(alg323.roll_mc().plot_histogram(title_prefix='323.').get_results(title_prefix='323.'))
res.append(alg324.roll_mc().plot_histogram(title_prefix='324.').get_results(title_prefix='324.'))
res.append(alg325.roll_mc().plot_histogram(title_prefix='325.').get_results(title_prefix='325.'))
res.append(alg326.roll_mc().plot_histogram(title_prefix='326.').get_results(title_prefix='326.'))
res.append(alg327.roll_mc().plot_histogram(title_prefix='327.').get_results(title_prefix='327.'))
res.append(alg328.roll_mc().plot_histogram(title_prefix='328.').get_results(title_prefix='328.'))
res.append(alg329.roll_mc().plot_histogram(title_prefix='329.').get_results(title_prefix='329.'))
res.append(alg330.roll_mc().plot_histogram(title_prefix='330.').get_results(title_prefix='330.'))
res.append(alg331.roll_mc().plot_histogram(title_prefix='331.').get_results(title_prefix='331.'))
res.append(alg332.roll_mc().plot_histogram(title_prefix='332.').get_results(title_prefix='332.'))
res.append(alg333.roll_mc().plot_histogram(title_prefix='333.').get_results(title_prefix='333.'))
res.append(alg334.roll_mc().plot_histogram(title_prefix='334.').get_results(title_prefix='334.'))
res.append(alg335.roll_mc().plot_histogram(title_prefix='335.').get_results(title_prefix='335.'))
res.append(alg336.roll_mc().plot_histogram(title_prefix='336.').get_results(title_prefix='336.'))

# %%
import pandas as pd
df = pd.DataFrame(data=res)
df.to_csv('Over300RollingMethods_1000000histories_output.csv')
